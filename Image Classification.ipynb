# %%
pip install tensorflow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
import tensorflow as tf

# %%
import numpy as np

# %%
filename = 'indian_currency_new//training//10//2.jpg'

# %% [markdown]
# # First Method to load an Image

# %%
from IPython.display import Image ### First method to read image Using IPython Method
Image(filename = 'indian_currency_new//training//10//2.jpg', width = 224, height = 224)

# %% [markdown]
# # Second Method to load an Image

# %%
from tensorflow.keras.preprocessing import image
img = image.load_img(filename, target_size = (224,224))   # Using Keras API to load an Image [Keras is already present in Tensorflow]

# %%
import matplotlib.pyplot as plt  # Import Used to display the image

# %%
plt.imshow(img)

# %% [markdown]
# # Third method to Load an Image

# %%
import cv2   ### pip install opencv-python
              # Using OpenCV method to load an image

# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
imgg = cv2.imread(filename)

# %%
plt.imshow(imgg)  ## Note that Colors of the image are changed
                  ## Always remember the color in this method is not RGB, it is BGR

# %%
imgg = cv2.resize(imgg, (224,224))    ## Changing the size of the image

# %%
plt.imshow(imgg)

# %%
## Changing the color of the image from BGR to RGB
plt.imshow(cv2.cvtColor(imgg, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # Fourth Method to load an image

# %%
## Using Python Image library that is PIL (Python Imaging Library)
from PIL import Image  ### pip install Pillow

# %%
im = Image.open(filename) ## PIL  ## Storing of the image in the variable

# %%
plt.imshow(im)

# %%
## To resize the image
im = im.resize((224, 224))

# %%
plt.imshow(im)

# %% [markdown]
# # Lets load the deep learning model

# %%
mobile = tf.keras.applications.  ## Deep Learning model weights -- Pre Trained

# %%
mobile1 = tf.keras.applications.mobilenet_v2.MobileNetV2()

# %%
## Creating the model
## Training the model  (Teaching the machine that this is Cat or Dog)
## test or validate it  (Giving labels)
## Predict

# %%
## Before we do Prediction of the Image, we need to Pre-Processing of the Image

# %% [markdown]
# # Pre-Processing of the Image

# %%
from tensorflow.keras.preprocessing import image
img = image.load_img(filename, target_size = (224,224))

# %%
plt.imshow(img)

# %%
resized_img = image.img_to_array(img)
final_image = np.expand_dims(resized_img, axis = 0)  ## need fourth dimension
final_image = tf.keras.applications.mobilenet.preprocess_input(final_image)

# %%
resized_img.shape
# Out:
# (224, 224, 3)

# %%
final_image.shape
# Out:
# (1, 224, 224, 3)

# %%
predictions = mobile.predict(final_image)

# %%
print(predictions)   ## Prediction of the Image without the Labels
# Out:
# [[6.11707208e-07 6.73191153e-07 1.76003880e-07 4.85470650e-08
#   8.35270075e-09 6.09087328e-06 6.93347744e-08 4.69041709e-07
#   1.05021290e-05 1.57237755e-05 4.94522112e-07 1.49965629e-07
#   4.21468371e-07 4.53419034e-06 2.63902905e-07 2.03572472e-06
#   2.21024084e-06 5.73765703e-07 1.87997455e-06 1.95474968e-07
#   3.22654586e-07 9.82951133e-06 5.46312913e-05 9.69827056e-07
#   3.95896086e-06 5.36118250e-07 1.50781617e-07 6.14873102e-07
#   1.40248957e-07 3.77876006e-07 5.93887108e-08 3.22022409e-08
#   3.98043403e-06 1.08611232e-06 3.94068047e-06 2.49670188e-06
#   2.88119440e-06 1.22675283e-06 1.29448154e-06 1.41373746e-07
#   8.30049828e-07 1.85589920e-06 1.35668458e-07 2.77211257e-06
#   3.14756653e-06 5.63976528e-06 3.03794081e-07 2.24578486e-07
#   7.38161958e-08 3.18051178e-07 5.14774392e-08 2.24564012e-08
#   7.97563985e-07 7.62866193e-07 1.95731630e-07 1.70164824e-08
#   7.97775073e-08 4.01099243e-07 1.40744717e-07 9.26694270e-07
# ...

# %%
from tensorflow.keras.applications import imagenet_utils   ## Using Imagenet as a dataset for labeling

# %%
results = imagenet_utils.decode_predictions(predictions)
# Out:
# ...
# 49152/35363 [=========================================] - 0s 1us/step

# %%
print(results)
# Out:
# [[('n03291819', 'envelope', 0.40517575), ('n03998194', 'prayer_rug', 0.27751985), ('n06359193', 'web_site', 0.097262025), ('n03127925', 'crate', 0.043204855), ('n03871628', 'packet', 0.034918524)]]

# %%
plt.imshow(img)

# %% [markdown]
# ### Performing Predictions using Mobilenet Version 2

# %%
predictions = mobile1.predict(final_image)

# %%
results = imagenet_utils.decode_predictions(predictions)

# %%
print(results)
# Out:
# [[('n03291819', 'envelope', 0.507642), ('n03485794', 'handkerchief', 0.15316841), ('n07248320', 'book_jacket', 0.0562225), ('n03998194', 'prayer_rug', 0.032528657), ('n02840245', 'binder', 0.01975188)]]
